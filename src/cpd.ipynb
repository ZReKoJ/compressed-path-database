# %% [markdown]
# -3: Null Values
# -2: Color values
# -1: Blocks
# 0: Start
# > 0: Distances

# %% [markdown]
# # Imports

# %%
from PIL import Image
import numpy as np
import pandas as pd
from queue import Queue

# %% [markdown]
# # Classes

# %%
class Coordinate():
    def __init__(self, i, j):
        self.i = i
        self.j = j

    def isEqual(self, that):
        return self.i == that.i and self.j == that.j

    def distanceTo(self, that):
        return math.sqrt(((self.i - that.i) ** 2) + ((self.j - that.j) ** 2))

    def toString(self):
        return str("[" + str(self.i) + ", " + str(self.j) + "]")

    def range(self, fromNode, toNode):
        return (fromNode.i <= self.i and self.i <= toNode.i and fromNode.j <= self.j and self.j <= toNode.j)

    def setIdentifier(self, identifier):
        self.identifier = identifier
    
    def surrounding(self):
        return [
            Coordinate(self.i, self.j + 1), # to EAST
            Coordinate(self.i + 1, self.j), # to SOUTH
            Coordinate(self.i, self.j - 1), # to WEST
            Coordinate(self.i - 1, self.j) # to NORTH
        ]
    
    def getDirection(self, that):
        i = self.i - that.i
        j = self.j - that.j
        if i != 0:
            return 'N' if i > 0 else 'S'
        elif j != 0:
            return 'W' if j > 0 else 'E'
        else:
            return None

# %% [markdown]
# # Utils

# %%
def isDigit(n):
    try:
        int(n)
        return True
    except ValueError:
        return  False

# %% [markdown]
# # Functions

# %%
def imageToMatrix(image_path, width=None, height=None, threshold=128):

    image = Image.open(image_path)
    image_grey = image.convert('L')

    image_binary = image_grey.point(lambda point : point > threshold and 1)

    if (width is not None and height is not None):
        image_binary = image_binary.resize((width, height), Image.NEAREST)

    nparray = np.array(image_binary).astype(int)
    nparray[nparray == 0] = -1
    nparray[nparray == 1] = -2
    return nparray

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 5)

def printMatrix_color(value):
    if isinstance(value, str) and not isDigit(value):
        if value == 'E':
            color = 'yellow'
        elif value == 'W':
            color = 'green'
        elif value == 'N':
            color = 'cyan'
        elif value == 'S':
            color = 'blue'
        else:
            color = 'white'
    else:
        value = int(value)
        if value == -1:
            color = 'black'
        elif value == -2:
            color = 'white'
        elif value == 0:
            color = 'green'
        else:
            color = 'white'
    return 'background-color: %s' % color

def printMatrix(matrix):
    df = pd.DataFrame(matrix)
    return df.style.applymap(printMatrix_color)

# %%
def createBFSMatrix(matrix, c):
    BFSMatrix = np.full(matrix.shape, -1)
    BFSMatrix[c.i, c.j] = 0
    fifo = Queue()
    fifo.put(c)
    while not fifo.empty():
        c = fifo.get()
        value = BFSMatrix[c.i, c.j]
        for s in c.surrounding():
            # if in matrix range and the cell is not a block
            if s.range(Coordinate(0, 0), Coordinate(matrix.shape[0] - 1, matrix.shape[1] - 1)):
                if BFSMatrix[s.i, s.j] == -1 and matrix[s.i, s.j] == -2:
                    BFSMatrix[s.i, s.j] = value + 1
                    fifo.put(s)
    return BFSMatrix

# %%
def createDirectionMatrix(BFSMatrix):
    directionMatrix = np.full(matrix.shape, '-1')
    for row, col in np.ndindex(directionMatrix.shape):
        c = Coordinate(row, col)
        if BFSMatrix[c.i, c.j] > 0: 
            minimum = float('inf')
            resultCoord = c
            for s in c.surrounding():
                # if in matrix range and the cell is not a block
                if s.range(Coordinate(0, 0), Coordinate(directionMatrix.shape[0] - 1, directionMatrix.shape[1] - 1)):
                    if BFSMatrix[s.i, s.j] >= 0 and BFSMatrix[s.i, s.j] < minimum:
                        resultCoord = s
                        minimum = BFSMatrix[s.i, s.j]
            letter = c.getDirection(resultCoord)
            if letter is not None:
                directionMatrix[c.i, c.j] = letter
    return directionMatrix

# %%
def createBFSDepthMatrix(matrix, c):
    BFSDepthMatrix = np.full((5, matrix.shape[0], matrix.shape[1]), -1)
    for it in range(0, 5):
        BFSDepthMatrix[it, c.i, c.j] = 0
    fifo = Queue()
    for index, s in enumerate(c.surrounding()):
        # if in matrix range and the cell is not a block
        if s.range(Coordinate(0, 0), Coordinate(matrix.shape[0] - 1, matrix.shape[1] - 1)) and matrix[s.i, s.j] == -2:
            s.setIdentifier(index + 1)
            fifo.put(s)
            BFSDepthMatrix[s.identifier, s.i, s.j] = 1
    while not fifo.empty():
        c = fifo.get()
        value = BFSDepthMatrix[c.identifier, c.i, c.j]
        for index, s in enumerate(c.surrounding()):
            # if in matrix range and the cell is not a block
            if s.range(Coordinate(0, 0), Coordinate(matrix.shape[0] - 1, matrix.shape[1] - 1)) and matrix[s.i, s.j] == -2:
                s.setIdentifier(index + 1)
                # if has no value set and not the same direction coming from
                if BFSDepthMatrix[s.identifier, s.i, s.j] == -1 and s.identifier != ((c.identifier + 2) % 4):
                    fifo.put(s)
                    BFSDepthMatrix[s.identifier, s.i, s.j] = value + 1
                    
    for row, col in np.ndindex(BFSDepthMatrix[0].shape):
        values = BFSDepthMatrix[1:, row, col]
        values = values[values != -1]
        if values.size > 0:
            BFSDepthMatrix[0, row, col] = min(values)
    return BFSDepthMatrix

# %%
def editCell(BFSDepthMatrix, c):
    modifiedMatrix = np.full((6, BFSDepthMatrix[0].shape[0], BFSDepthMatrix[0].shape[1]), 0)
    modifiedMatrix[:-1, :, :] = BFSDepthMatrix
    if BFSDepthMatrix[0, c.i, c.j] > 0:
        print("Not Done Yet")
    else:
        fifo = Queue()
        for index, s in enumerate(c.surrounding()):
            # if in matrix range and the cell is not a block
            if s.range(Coordinate(0, 0), Coordinate(modifiedMatrix[0].shape[0] - 1, modifiedMatrix[0].shape[1] - 1)) and BFSDepthMatrix[0, s.i, s.j] != -1:
                # Reverse direction
                fromIndex = (index + 1 + 2) % 4
                # reachable
                if modifiedMatrix[fromIndex, s.i, s.j] != -1:
                    modifiedMatrix[fromIndex, c.i, c.j] = modifiedMatrix[0, s.i, s.j] + 1
                    initCoord = Coordinate(c.i, c.j)
                    initCoord.setIdentifier(fromIndex)
                    fifo.put(initCoord)
    while not fifo.empty():
        c = fifo.get()
        value = modifiedMatrix[c.identifier, c.i, c.j]
        for index, s in enumerate(c.surrounding()):
            # if in matrix range and the cell is not a block
            if s.range(Coordinate(0, 0), Coordinate(modifiedMatrix[0].shape[0] - 1, modifiedMatrix[0].shape[1] - 1)) and matrix[s.i, s.j] == -2:
                s.setIdentifier(index + 1)
                # if has no value set and not the same direction coming from
                if s.identifier != ((c.identifier + 2) % 4):
                    if (value + 1 < modifiedMatrix[s.identifier, s.i, s.j] or modifiedMatrix[s.identifier, s.i, s.j] == -1):
                        fifo.put(s)
                        modifiedMatrix[s.identifier, s.i, s.j] = value + 1
                        modifiedMatrix[5, s.i, s.j] = modifiedMatrix[5, s.i, s.j] + 1
    for row, col in np.ndindex(modifiedMatrix[0].shape):
        values = modifiedMatrix[1:5, row, col]
        values = values[values != -1]
        if values.size > 0:
            modifiedMatrix[0, row, col] = min(values)
    return modifiedMatrix
        
BFSDepthMatrix = createBFSDepthMatrix(matrix, Coordinate(0, 1))
modifiedMatrix = editCell(BFSDepthMatrix, Coordinate(9, 11))
print(modifiedMatrix[1:5, 9, 11])
printMatrix(modifiedMatrix[5])

#Coordinate(self.i, self.j + 1), # to EAST
#Coordinate(self.i + 1, self.j), # to SOUTH
#Coordinate(self.i, self.j - 1), # to WEST
#Coordinate(self.i - 1, self.j) # to NORTH
# Out:
# [21 19 23 -1]
# <style  type="text/css" >
#     #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col0 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col1 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col2 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col3 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col4 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col5 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col6 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col7 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col8 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col9 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col10 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col11 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col12 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col13 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col14 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col15 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col16 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col17 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col18 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col19 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col20 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col21 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col22 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col23 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col24 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col25 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col26 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col27 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col28 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row0_col29 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col0 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col1 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col2 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col3 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col4 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col5 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col6 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col7 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col8 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col9 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col10 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col11 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col12 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col13 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col14 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col15 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col16 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col17 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col18 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col19 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col20 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col21 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col22 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col23 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col24 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col25 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col26 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col27 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col28 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row1_col29 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col0 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col1 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col2 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col3 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col4 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col5 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col6 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col7 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col8 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col9 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col10 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col11 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col12 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col13 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col14 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col15 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col16 {
#             background-color:  green;
#         }    #T_afd1834c_a07f_11eb_99d4_0c84dcdcd698row2_col17 {
#             backg

# %% [markdown]
# # Environment Variables

# %%
FILENAME = 'D:/compressed-path-database/resources/labyrinth_2.png'
MATRIX_WIDTH = 30
MATRIX_HEIGHT = 20

# %% [markdown]
# # Execution

# %%
matrix = imageToMatrix(FILENAME, MATRIX_WIDTH, MATRIX_HEIGHT)
printMatrix(matrix)
# Out:
# <style  type="text/css" >
#     #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col0 {
#             background-color:  black;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col1 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col2 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col3 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col4 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col5 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col6 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col7 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col8 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col9 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col10 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col11 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col12 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col13 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col14 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col15 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col16 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col17 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col18 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col19 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col20 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col21 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col22 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col23 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col24 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col25 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col26 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col27 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col28 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row0_col29 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col0 {
#             background-color:  black;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col1 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col2 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col3 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col4 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col5 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col6 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col7 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col8 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col9 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col10 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col11 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col12 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col13 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col14 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col15 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col16 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col17 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col18 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col19 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col20 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col21 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col22 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col23 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col24 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col25 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col26 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col27 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col28 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row1_col29 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col0 {
#             background-color:  black;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col1 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col2 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col3 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col4 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col5 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col6 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col7 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col8 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col9 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col10 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col11 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col12 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col13 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col14 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col15 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col16 {
#             background-color:  white;
#         }    #T_a5149a5e_a05d_11eb_a0ae_0c84dcdcd698row2_col17 {
#             backg

# %%
BFSMatrix = createBFSMatrix(matrix, Coordinate(0, 1))
printMatrix(BFSMatrix)
# Out:
# <style  type="text/css" >
#     #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col0 {
#             background-color:  black;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col1 {
#             background-color:  green;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col2 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col3 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col4 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col5 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col6 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col7 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col8 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col9 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col10 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col11 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col12 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col13 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col14 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col15 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col16 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col17 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col18 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col19 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col20 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col21 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col22 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col23 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col24 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col25 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col26 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col27 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col28 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row0_col29 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col0 {
#             background-color:  black;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col1 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col2 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col3 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col4 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col5 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col6 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col7 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col8 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col9 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col10 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col11 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col12 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col13 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col14 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col15 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col16 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col17 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col18 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col19 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col20 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col21 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col22 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col23 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col24 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col25 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col26 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col27 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col28 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row1_col29 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col0 {
#             background-color:  black;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col1 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col2 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col3 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col4 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col5 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col6 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col7 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col8 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col9 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col10 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col11 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col12 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col13 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col14 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col15 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col16 {
#             background-color:  white;
#         }    #T_ec87b788_a07a_11eb_85bc_0c84dcdcd698row2_col17 {
#             backg

# %%
directionMatrix = createDirectionMatrix(BFSMatrix)
printMatrix(directionMatrix)
# Out:
# <style  type="text/css" >
#     #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col0 {
#             background-color:  black;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col1 {
#             background-color:  black;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col2 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col3 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col4 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col5 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col6 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col7 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col8 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col9 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col10 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col11 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col12 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col13 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col14 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col15 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col16 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col17 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col18 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col19 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col20 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col21 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col22 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col23 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col24 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col25 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col26 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col27 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col28 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row0_col29 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col0 {
#             background-color:  black;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col1 {
#             background-color:  cyan;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col2 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col3 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col4 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col5 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col6 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col7 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col8 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col9 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col10 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col11 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col12 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col13 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col14 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col15 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col16 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col17 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col18 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col19 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col20 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col21 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col22 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col23 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col24 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col25 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col26 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col27 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col28 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row1_col29 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col0 {
#             background-color:  black;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col1 {
#             background-color:  cyan;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col2 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col3 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col4 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col5 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col6 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col7 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col8 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col9 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col10 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col11 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col12 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col13 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col14 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col15 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col16 {
#             background-color:  green;
#         }    #T_ed7697e2_a07a_11eb_a52d_0c84dcdcd698row2_col17 {
#             backgro

# %%
BFSDepthMatrix = createBFSDepthMatrix(matrix, Coordinate(0, 1))
printMatrix(BFSDepthMatrix[0])
# Out:
# <style  type="text/css" >
#     #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col0 {
#             background-color:  black;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col1 {
#             background-color:  green;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col2 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col3 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col4 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col5 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col6 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col7 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col8 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col9 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col10 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col11 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col12 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col13 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col14 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col15 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col16 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col17 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col18 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col19 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col20 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col21 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col22 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col23 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col24 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col25 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col26 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col27 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col28 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row0_col29 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col0 {
#             background-color:  black;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col1 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col2 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col3 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col4 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col5 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col6 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col7 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col8 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col9 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col10 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col11 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col12 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col13 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col14 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col15 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col16 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col17 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col18 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col19 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col20 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col21 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col22 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col23 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col24 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col25 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col26 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col27 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col28 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row1_col29 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col0 {
#             background-color:  black;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col1 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col2 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col3 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col4 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col5 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col6 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col7 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col8 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col9 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col10 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col11 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col12 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col13 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col14 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col15 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col16 {
#             background-color:  white;
#         }    #T_ee4b7706_a07a_11eb_8978_0c84dcdcd698row2_col17 {
#             backg

# %%
directionDepthMatrix = createDirectionMatrix(BFSDepthMatrix[0])
printMatrix(directionDepthMatrix)
# Out:
# <style  type="text/css" >
#     #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col0 {
#             background-color:  black;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col1 {
#             background-color:  black;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col2 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col3 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col4 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col5 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col6 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col7 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col8 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col9 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col10 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col11 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col12 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col13 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col14 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col15 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col16 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col17 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col18 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col19 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col20 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col21 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col22 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col23 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col24 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col25 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col26 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col27 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col28 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row0_col29 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col0 {
#             background-color:  black;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col1 {
#             background-color:  cyan;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col2 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col3 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col4 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col5 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col6 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col7 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col8 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col9 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col10 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col11 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col12 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col13 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col14 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col15 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col16 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col17 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col18 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col19 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col20 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col21 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col22 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col23 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col24 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col25 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col26 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col27 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col28 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row1_col29 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col0 {
#             background-color:  black;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col1 {
#             background-color:  cyan;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col2 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col3 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col4 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col5 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col6 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col7 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col8 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col9 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col10 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col11 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col12 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col13 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col14 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col15 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col16 {
#             background-color:  green;
#         }    #T_eef1eda2_a07a_11eb_9f4c_0c84dcdcd698row2_col17 {
#             backgro

# %%
printMatrix(BFSDepthMatrix[0])
# Out:
# <style  type="text/css" >
#     #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col0 {
#             background-color:  black;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col1 {
#             background-color:  green;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col2 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col3 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col4 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col5 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col6 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col7 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col8 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col9 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col10 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col11 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col12 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col13 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col14 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col15 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col16 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col17 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col18 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col19 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col20 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col21 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col22 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col23 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col24 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col25 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col26 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col27 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col28 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row0_col29 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col0 {
#             background-color:  black;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col1 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col2 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col3 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col4 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col5 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col6 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col7 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col8 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col9 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col10 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col11 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col12 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col13 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col14 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col15 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col16 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col17 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col18 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col19 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col20 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col21 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col22 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col23 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col24 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col25 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col26 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col27 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col28 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row1_col29 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col0 {
#             background-color:  black;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col1 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col2 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col3 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col4 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col5 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col6 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col7 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col8 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col9 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col10 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col11 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col12 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col13 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col14 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col15 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col16 {
#             background-color:  white;
#         }    #T_efb3839e_a07a_11eb_a341_0c84dcdcd698row2_col17 {
#             backg
